# %%
# %pip install roboflow
# %pip install ultralytics
# Out:
# ...
#    ---------------------------------------- 0.0/74.1 kB ? eta -:--:--
#    -------------------------------------- - 71.7/74.1 kB 2.0 MB/s eta 0:00:01
#    ---------------------------------------- 74.1/74.1 kB 1.4 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/158.3 kB ? eta -:--:--
#    ---------------------------------------- 158.3/158.3 kB 4.6 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/58.8 kB ? eta -:--:--
#    ---------------------------------------- 58.8/58.8 kB 3.2 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/38.0 MB ? eta -:--:--
#    ---------------------------------------- 0.1/38.0 MB 2.4 MB/s eta 0:00:16
#    ---------------------------------------- 0.2/38.0 MB 2.1 MB/s eta 0:00:19
#    ---------------------------------------- 0.3/38.0 MB 2.1 MB/s eta 0:00:18
#    ---------------------------------------- 0.4/38.0 MB 2.2 MB/s eta 0:00:18
# ...

# %%
import shutil

# %%
shutil.move("tennis-ball-detection-6/train", "tennis-ball-detection-6/tennis-ball-detection-6/train")
shutil.move("tennis-ball-detection-6/test", "tennis-ball-detection-6/tennis-ball-detection-6/test")
shutil.move("tennis-ball-detection-6/validation", "tennis-ball-detection-6/tennis-ball-detection-6/validation")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File c:\Users\willi\anaconda3\lib\shutil.py:825, in move(src, dst, copy_function)
#     824 try:
# --> 825     os.rename(src, real_dst)
#     826 except OSError:
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'tennis-ball-detection-6/train' -> 'tennis-ball-detection-6/tennis-ball-detection-6/train'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 shutil.move("tennis-ball-detection-6/train", "tennis-ball-detection-6/tennis-ball-detection-6/train")
#       2 shutil.move("tennis-ball-detection-6/test", "tennis-ball-detection-6/tennis-ball-detection-6/test")
# ...

# %%
# !yolo task=detect mode=train model=yolov5l6u.py data={dataset.location}/data.yaml epochs=100 imgsz=640
